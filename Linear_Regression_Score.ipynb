# %%
def scoring(t, predicted, actual):
  print(f'{t} r2 ',r2_score(actual,predicted))
  print(f'{t} mean_absolute_percentage_error ',mean_absolute_percentage_error(actual,predicted)* 100)
  print(f'{t} mean_squared_error ',mean_squared_error(actual,predicted))
  print(f'{t} mean_absolute_error ',mean_absolute_error(actual,predicted))
def score(model, X_train, X_test, Y_train, Y_test):
  test_pred = model.predict(X_test)
  train_pred = model.predict(X_train)
  scoring("Test", test_pred, Y_test)
  scoring("Train", train_pred, Y_train)
